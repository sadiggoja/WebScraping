# %%
import requests
from bs4 import BeautifulSoup
from csv import writer
from time import sleep
import pandas as pd

# %%
base="https://acqalma.az/restaurants"

# %%
response=requests.get(base)
page=BeautifulSoup(response.text,"html.parser")

# %%
rest_sections=page.find_all(class_='restaurant')

# %%
rests=[]
for rest_div in rest_sections:
    rest=dict()
    rest['Ad']=rest_div.find('span').text
    rest['url']=rest_div.find('a').get('href')
    rest['img']=rest_div.find('img').get('data-original')
    cuisine_prop=rest_div.find(class_='restaurant__cuisines').text.strip().split(':')
    rest[cuisine_prop[0]]=cuisine_prop[1]
    rests.append(rest)

# %%
rest_frame=pd.DataFrame(rests)
rest_frame
# Out:
#                            Ad  \
# 0      Adana Lahmacun (Xətai)
# 1    Adana Lahmacun (Yasamal)
# 2         Anadolu Restaurants
# 3   Başkent Restoran (28 May)
# 4    Başkent Restoran (3 mkr)
# 5                 Bella Pizza
# 6               Galileo Pizza
# 7    Lənkəran Süfrəsi (8 mkr)
# 8       Ləziz House (Yasamal)
# 9             Merkez Lahmacun
# 10        New York Pizza Baku
# 11               Sushi Nooshi
#
#                                                   url  \
# 0   https://acqalma.az/restaurant/adana-lahmacun-xtai
# 1   https://acqalma.az/restaurant/adana-lahmacun-y...
# 2   https://acqalma.az/restaurant/anadolu-restaurants
# 3   https://acqalma.az/restaurant/bakent-restoran-...
# 4   https://acqalma.az/restaurant/bakent-restoran-...
# 5           https://acqalma.az/restaurant/bella-pizza
# 6         https://acqalma.az/restaurant/galileo-pizza
# 7    https://acqalma.az/restaurant/lnkran-sfrsi-8-mkr
# 8    https://acqalma.az/restaurant/lziz-house-yasamal
# 9       https://acqalma.az/restaurant/merkez-lahmacun
# 10  https://acqalma.az/restaurant/new-york-pizza-baku
# 11         https://acqalma.az/restaurant/sushi-nooshi
#
#                                                   img  \
# 0   https://acqalma.az/uploads/tmp/images/8f1b1b71...
# 1   https://acqalma.az/uploads/tmp/images/e07406c3...
# 2   https://acqalma.az/uploads/tmp/images/6685532d...
# 3   https://acqalma.az/uploads/tmp/images/b613021e...
# 4   https://acqalma.az/uploads/tmp/images/c59f9b29...
# 5   https://acqalma.az/uploads/tmp/images/c17a6dfd...
# 6   https://acqalma.az/uploads/tmp/images/d20c220d...
# 7   https://acqalma.az/uploads/tmp/images/f1ac4a73...
# 8   https://acqalma.az/uploads/tmp/images/13a41773...
# 9   https://acqalma.az/uploads/tmp/images/ab5042fa...
# 10  https://acqalma.az/uploads/tmp/images/874ee2d7...
# 11  https://acqalma.az/uploads/tmp/images/6e1c359c...
#
#                                 Mətbəx
# 0                     Azərbaycan, Türk
# 1                     Azərbaycan, Türk
# 2    İtalyan, Azərbaycan, Türk, Avropa
# 3             Azərbaycan, Türk, Avropa
# 4    İtalyan, Azərbaycan, Türk, Avropa
# 5           İtalyan, Avropa, Fast food
# 6           İtalyan, Avropa, Fast food
# 7                           Azərbaycan
# 8             Azərbaycan, Türk, Avropa
# 9             Azərbaycan, Türk, Avropa
# 10          İtalyan, Avropa, Fast food
# 11                               Yapon

# %%
foods=[]
for rest in rests:
    response=requests.get(rest['url'])
    rest_page=BeautifulSoup(response.text, 'html.parser')

    categories_div=rest_page.find_all(class_='restaurant__content__menu-category')
    for category_div in categories_div:
        category=category_div.find('a').text.strip()
        foods_div=category_div.find_all(class_='menu-item__inner')
        
        for food_div in foods_div:
            food=dict()
            food['name']=food_div.find(class_='menu-item__title').text.strip()
            food['image']=food_div.find('img').get('data-original')
            food['price']=food_div.find('span').text
            food['restaurant']=rest['Ad']
            foods.append(food)
    print(rest['Ad']+' is done')
    sleep(0.5)
# Out:
# Adana Lahmacun (Xətai) is done
# Adana Lahmacun (Yasamal) is done
# Anadolu Restaurants is done
# Başkent Restoran (28 May) is done
# Başkent Restoran (3 mkr) is done
# Bella Pizza is done
# Galileo Pizza is done
# Lənkəran Süfrəsi (8 mkr) is done
# Ləziz House (Yasamal) is done
# Merkez Lahmacun is done
# New York Pizza Baku is done
# Sushi Nooshi is done

# %%
food_frame=pd.DataFrame(foods)
food_frame
# Out:
#                         name  \
# 0     Pomidor yumurta omleti
# 1              Pendirli tost
# 2            Sosiska yumurta
# 3                Biznes Lanç
# 4               Çoban salatı
# ...                      ...
# 1191            Sushi Burger
# 1192          Sushi sandwich
# 1193              Sushi tort
# 1194                 3 Biber
# 1195  Salat Tempura Krevetka
#
#                                                   image      price  \
# 0     https://acqalma.az/uploads/tmp/images/9c3389a4...    4.00 M
# 1     https://acqalma.az/uploads/tmp/images/2c0211db...    3.00 M
# 2     https://acqalma.az/uploads/tmp/images/d9f81b62...    3.00 M
# 3     https://acqalma.az/uploads/tmp/images/b93d07ea...    5.00 M
# 4     https://acqalma.az/uploads/tmp/images/8359c25e...    1.80 M
# ...                                                 ...        ...
# 1191  https://acqalma.az/uploads/tmp/images/f54a90d3...   13.00 M
# 1192  https://acqalma.az/uploads/tmp/images/8cb61807...   11.00 M
# 1193  https://acqalma.az/uploads/tmp/images/93234f29...   14.00 M
# 1194  https://acqalma.az/uploads/tmp/images/92238e61...    8.00 M
# 1195  https://acqalma.az/uploads/tmp/images/2a3c4b8d...   11.00 M
#
#                   restaurant
# 0     Adana Lahmacun (Xətai)
# 1     Adana Lahmacun (Xətai)
# 2     Adana Lahmacun (Xətai)
# 3     Adana Lahmacun (Xətai)
# 4     Adana Lahmacun (Xətai)
# ...                      ...
# 1191            Sushi Nooshi
# 1192            Sushi Nooshi
# 1193            Sushi Nooshi
# 1194            Sushi Nooshi
# 1195            Sushi Nooshi
#
# [1196 rows x 4 columns]

# %%
rest_frame.to_csv('acqalma_rests.csv')
food_frame.to_csv('acqalma_foods.csv')
